# %% [markdown]
# # Rappels

# %% [markdown]
# Filtrage

# %%
import numpy as np 
import pandas 
df = pandas.DataFrame(np.arange(16).reshape(4,4), index=["Ohio", "Colorado", "Utah", "New York"], columns=["one", "two", "three", "four"])
df
# Out:
#           one  two  three  four
# Ohio        0    1      2     3
# Colorado    4    5      6     7
# Utah        8    9     10    11
# New York   12   13     14    15

# %%
# Selectionner une sous-partie du DF
# 1. ligne Colorado, colonnes "two" et "three"
# obtenu avec .loc[] : requête par nom
df.loc["Colorado", ["two", "three"]]
# Out:
# two      5
# three    6
# Name: Colorado, dtype: int64

# %%
# 2. toutes les lignes, colonnes "two" et "three"
df.loc[:, ["two", "three"]]
# Out:
#           two  three
# Ohio        1      2
# Colorado    5      6
# Utah        9     10
# New York   13     14

# %%
# 3. toutes les lignes, colonnes "two" à "four"
df.loc[:, "two": "four"]
# Out:
#           two  three  four
# Ohio        1      2     3
# Colorado    5      6     7
# Utah        9     10    11
# New York   13     14    15

# %%
# 4. lignes jusqu'a "Utah", colonne "two"
df.loc[:"Utah", "two"]
# Out:
# Ohio        1
# Colorado    5
# Utah        9
# Name: two, dtype: int64

# %%
# Selectionner une sous-partie du DF: une seule ligne
df.loc["Utah",:]
# Out:
# one       8
# two       9
# three    10
# four     11
# Name: Utah, dtype: int64

# %%
# Selectionner une sous-partie du DF : une seule colonne
df.loc[:,"one"]
# Out:
# Ohio         0
# Colorado     4
# Utah         8
# New York    12
# Name: one, dtype: int64

# %%
# Selectionner une sous-partie du DF
# Traiter les cas plus complexes
df.loc[lambda df: df.index.str.len() > 4]
# Out:
#           one  two  three  four
# Colorado    4    5      6     7
# New York   12   13     14    15

# %% [markdown]
# Données manquantes

# %%
string_data = pandas.Series(["aarggfx", "artichaut", np.nan, "avocado"])
string_data.isnull()
# Out:
# 0    False
# 1    False
# 2     True
# 3    False
# dtype: bool

# %%
# Par défaut, .dropna() supprime des lignes ("axis = 0")
df_with_na = pandas.DataFrame(
    [[1, np.nan], [2, 3], [np.nan, 7]], 
    index= ["a", "b", "c"], 
    columns = ["A", "B"])
df_with_na
# Out:
#      A    B
# a  1.0  NaN
# b  2.0  3.0
# c  NaN  7.0

# %%
df_with_na.dropna()
# Out:
#      A    B
# b  2.0  3.0

# %%
# Il peut aussi supprimer des colonnes
df_with_na.dropna(axis=1)
# Out:
# Empty DataFrame
# Columns: []
# Index: [a, b, c]

# %%
# .fillna()
value_to_replace_na_with = 0
df_with_na.fillna(value_to_replace_na_with)
# Out:
#      A    B
# a  1.0  0.0
# b  2.0  3.0
# c  0.0  7.0

# %%
# .fillna() avec dict
value_to_replace_na_with = {"A":1, "B":3}
df_with_na.fillna(value_to_replace_na_with)
# Out:
#      A    B
# a  1.0  3.0
# b  2.0  3.0
# c  1.0  7.0

# %% [markdown]
# Exercices

# %%
# Lire les données du Titanic
# Créer un dataframe avec 100 lignes
from pandas import read_csv
url = 'https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv'
df_titanic = read_csv(url)
df_titanic
# Filtrer le df pour n'obtenir que les hommes qui ont payé plus de 50$
# Combien y en a-t-il ? 


df_titanic
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df_titanic.loc[(df_titanic["Fare"] > 50) & (df_titanic["Sex"] == "male")].shape[0]
# Out:
# 73

# %%
# Filtrer le df pour n'obtenir que les femmes de moins de 18 ans
# Combien y en a-t-il ? 
df_titanic.loc[(df_titanic["Age"] < 18) & (df_titanic["Sex"] == "female")].shape
# Out:
# (55, 12)

# %%
# Remplacer les valeurs manquantes de la colonne prix par le prix moyen, et les lieux d'embarquement manquants par "C"
# Est-il possible de faire cela en un seul appel ? 
df_titanic["Embarked"].fillna("C", inplace = True)
df_titanic["Fare"].fillna(df_titanic["Fare"].mean(), inplace = True)
# Out:
# /var/folders/fn/840kfjnd1f3cn2f5lqxn6ymr0000gp/T/ipykernel_85108/3722107139.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_titanic["Embarked"].fillna("C", inplace = True)
# /var/folders/fn/840kfjnd1f3cn2f5lqxn6ymr0000gp/T/ipykernel_85108/3722107139.py:4: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# ...

# %%
df_titanic.fillna({"Embarked" : "C"}, inplace = True)
df_titanic.fillna({"Fare" : df_titanic["Fare"].mean()}, inplace = True)

# %%
df_titanic.fillna({"Embarked" : "C", "Fare" : df_titanic["Fare"].mean()}, inplace = True)

# %%
# Bonus
# Supprimer les lignes où l'âge est manquant
df_titanic.dropna(subset="Age", inplace=True)

# %%
# Bonus
# Créer une fonction qui effectue les opérations des trois cellules précédentes
def clean_df(df: pandas.DataFrame) -> pandas.DataFrame:
    return (df.loc[(df["Age"] < 18)& (df["Sex"] == "female")]
    .fillna({"Embarked" : "C", "Fare" : df["Fare"].mean()})
    .dropna(subset="Age"))

    
clean_df(df_titanic)
# Out:
#      PassengerId  Survived  Pclass  \
# 9             10         1       2
# 10            11         1       3
# 14            15         0       3
# 22            23         1       3
# 24            25         0       3
# 39            40         1       3
# 43            44         1       2
# 58            59         1       2
# 68            69         1       3
# 71            72         0       3
# 84            85         1       2
# 111          112         0       3
# 114          115         0       3
# 119          120         0       3
# 147          148         0       3
# 156          157         1       3
# 172          173         1       3
# 184          185         1       3
# 205          206         0       3
# 208          209         1       3
# 233          234         1       3
# 237          238         1       2
# 297          298         0       1
# 307          308         1       1
# 329          330         1       1
# ...

# %%
# Bonus : filtrage avancé
# Filtrer le df suivant pour ne garder que les lignes où le prénom commence par un "A"
data = {"prenom" : ["Anna", "Ben", "Camille"], "poste": ["DE", "DE", "DS"]}
df = pandas.DataFrame(data)


df.loc[lambda df : df["prenom"].str.startswith("A")]
# Out:
#   prenom poste
# 0   Anna    DE
